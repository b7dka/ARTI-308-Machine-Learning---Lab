# %%
import pandas as pd

df = pd.read_csv('/student_health_data.csv', sep=';')

print("Dataset Shape:", df.shape)

print("\nFirst 5 Rows:")
display(df.head())

print("\nColumn Names:")
print(df.columns)
# Out:
# Dataset Shape: (1000, 15)
#
# First 5 Rows:
#                                           Student_ID  Age  Gender  Heart_Rate  \
# 0  1,24,M,50.66321699,122.173015,84.41986006,3.13...  NaN     NaN         NaN
# 1  2,21,F,57.92604168,110.778407,75.69614524,3.69...  NaN     NaN         NaN
# 2  3,22,M,59.2942192,109.3756731,83.80381448,6.78...  NaN     NaN         NaN
# 3  4,24,M,76.82623236,125.1422274,78.09158681,6.4...  NaN     NaN         NaN
# 4  5,20,M,68.34276947,107.5155918,80.67493681,7.2...  NaN     NaN         NaN
#
#    Blood_Pressure_Systolic  Blood_Pressure_Diastolic  Stress_Level_Biosensor  \
# 0                      NaN                       NaN                     NaN
# 1                      NaN                       NaN                     NaN
# 2                      NaN                       NaN                     NaN
# 3                      NaN                       NaN                     NaN
# ...
